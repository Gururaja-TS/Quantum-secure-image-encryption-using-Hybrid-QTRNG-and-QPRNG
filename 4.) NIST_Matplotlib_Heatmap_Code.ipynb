# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Data for the heatmap
data = {
    "Frequency Test": [0.7552159745, 0.2309163129, 0.01982686116, 0.08275186564, 0.8783999934, 0.4866122943],
    "Frequency Test within a Block": [0.3550040436, 0.7204724606, 0.3316628045, 0.01921629392, 0.8037281527, 0.8962980698],
    "Run Test": [0.07486896735, 0.4193913836, 0.01596837013, 0.8772724987, 0.5933309915, 0.930432073],
    "Longest Run of Ones in a Block": [0.7269038021, 0.8036238113, 0.18890244, 0.8408665185, 0.5306661463, 0.1431913298],
    "Binary Matrix Rank Test": [0.9376631094, 0.9781466553, 0.3321142189, 0.2932268112, 0.400630382, 0.5514274252],
    "Discrete Fourier Transform (Spectral) Test": [0.8013029901, 0.5249227379, 0.9261281806, 0.3748438432, 0.6429441538, 0.6334820073],
    "Non-Overlapping Template Matching Test": [0.7020809557, 0.2017118362, 0.1811189667, 0.6321378017, 0.654936366, 0.8769640906],
    "Overlapping Template Matching Test": [0.3941880676, 0.6154020028, 0.06960688536, 0.7245850052, 0.6979578471, 0.3666727474],
    "Maurer's Universal Statistical test": [0.7061205355, 0.3335443554, 0.9688947705, 0.4983655174, 0.9063969634, 0.4224232214],
    "Linear Complexity Test": [0.2473091522, 0.8846568522, 0.4184021524, 0.09544776607, 0.01972851657, 0.6297072548],
    "Serial test a": [0.05752645645, 0.6968726289, 0.7958584403, 0.9587111574, 0.2592070436, 0.02081799495],
    "Serial test b": [0.1653215719, 0.5644858562, 0.8782501365, 0.8113296239, 0.2347754561, 0.251809969],
    "Approximate Entropy Test": [0.9999604737, 0.7704836636, 0.470117024, 0.4539078679, 0.3190821689, 0.09893491455],
    "Cumulative Sums (Forward) Test": [0.6342738832, 0.455638608, 0.02838962602, 0.1649926227, 0.7014177868, 0.687878607],
    "Cumulative Sums (Reverse) Test": [0.4678912192, 0.1540763822, 0.06010307574, 0.1318713131, 0.841644061, 0.4016636504],
    "Random Excursion Test": [0.6610658686, 0.6941332031, 0.5873421946, 0.5442743402, 0.3782924672, 0.6122280347],
    "Random Excursion Variant Test": [0.574647078, 0.42044434, 0.6131809837, 0.6770220551, 0.6165412815, 0.6165412815],
}
data = np.array([
    [0.7552159745, 0.2309163129, 0.01982686116, 0.08275186564, 0.8783999934, 0.4866122943],
    [0.3550040436, 0.7204724606, 0.3316628045, 0.01921629392, 0.8037281527, 0.8962980698],
    [0.07486896735, 0.4193913836, 0.01596837013, 0.8772724987, 0.5933309915, 0.930432073],
    [0.7269038021, 0.8036238113, 0.18890244, 0.8408665185, 0.5306661463, 0.1431913298],
    [0.9376631094, 0.9781466553, 0.3321142189, 0.2932268112, 0.400630382, 0.5514274252],
    [0.8013029901, 0.5249227379, 0.9261281806, 0.3748438432, 0.6429441538, 0.6334820073],
    [0.7020809557, 0.2017118362, 0.1811189667, 0.6321378017, 0.654936366, 0.8769640906],
    [0.3941880676, 0.6154020028, 0.06960688536, 0.7245850052, 0.6979578471, 0.3666727474],
    [0.7061205355, 0.3335443554, 0.9688947705, 0.4983655174, 0.9063969634, 0.4224232214],
    [0.2473091522, 0.8846568522, 0.4184021524, 0.09544776607, 0.01972851657, 0.6297072548],
    [0.05752645645, 0.6968726289, 0.7958584403, 0.9587111574, 0.2592070436, 0.02081799495],
    [0.1653215719, 0.5644858562, 0.8782501365, 0.8113296239, 0.2347754561, 0.251809969],
    [0.9999604737, 0.7704836636, 0.470117024, 0.4539078679, 0.3190821689, 0.09893491455],
    [0.6342738832, 0.455638608, 0.02838962602, 0.1649926227, 0.7014177868, 0.687878607],
    [0.4678912192, 0.1540763822, 0.06010307574, 0.1318713131, 0.841644061, 0.4016636504],
    [0.6610658686, 0.6941332031, 0.5873421946, 0.5442743402, 0.3782924672, 0.6122280347],
    [0.574647078, 0.42044434, 0.6131809837, 0.6770220551, 0.6165412815, 0.6165412815]
])

rows = [
     "Frequency Test",
     "Frequency Test within a Block",
     "Run Test",
     "Longest Run of Ones in a Block",
     "Binary Matrix Rank Test",
     "Discrete Fourier Transform (Spectral) Test",
     "Non-Overlapping Template Matching Test",
     "Overlapping Template Matching Test",
     "Maurer's Universal Statistical test",
     "Linear Complexity Test",
     "Serial test a",
     "Serial test b",
     "Approximate Entropy Test",
     "Cumulative Sums (Forward) Test",
     "Cumulative Sums (Reverse) Test",
     "Random Excursion Test",
     "Random Excursion Variant Test"
]
    
columns = ["Data 1a", "Data 1b", "Data 2a", "Data 2b", "Data 3a", "Data 3b"]
# Convert to DataFrame
df = pd.DataFrame(data).T

# Generate heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(df, annot=True, cmap="coolwarm", cbar_kws={'label': 'P-value'}, fmt=".3f")
plt.title("Heatmap of Statistical Test P-values")
plt.xlabel("Test Instances")
plt.ylabel("Tests")
plt.tight_layout()
plt.savefig("gururaja_1.tiff", dpi=300, bbox_inches="tight")  # Save as PNG with high resolution
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data = np.array([
    [0.7552159745, 0.2309163129, 0.01982686116, 0.08275186564, 0.8783999934, 0.4866122943],
    [0.3550040436, 0.7204724606, 0.3316628045, 0.01921629392, 0.8037281527, 0.8962980698],
    [0.07486896735, 0.4193913836, 0.01596837013, 0.8772724987, 0.5933309915, 0.930432073],
    [0.7269038021, 0.8036238113, 0.18890244, 0.8408665185, 0.5306661463, 0.1431913298],
    [0.9376631094, 0.9781466553, 0.3321142189, 0.2932268112, 0.400630382, 0.5514274252],
    [0.8013029901, 0.5249227379, 0.9261281806, 0.3748438432, 0.6429441538, 0.6334820073],
    [0.7020809557, 0.2017118362, 0.1811189667, 0.6321378017, 0.654936366, 0.8769640906],
    [0.3941880676, 0.6154020028, 0.06960688536, 0.7245850052, 0.6979578471, 0.3666727474],
    [0.7061205355, 0.3335443554, 0.9688947705, 0.4983655174, 0.9063969634, 0.4224232214],
    [0.2473091522, 0.8846568522, 0.4184021524, 0.09544776607, 0.01972851657, 0.6297072548],
    [0.05752645645, 0.6968726289, 0.7958584403, 0.9587111574, 0.2592070436, 0.02081799495],
    [0.1653215719, 0.5644858562, 0.8782501365, 0.8113296239, 0.2347754561, 0.251809969],
    [0.9999604737, 0.7704836636, 0.470117024, 0.4539078679, 0.3190821689, 0.09893491455],
    [0.6342738832, 0.455638608, 0.02838962602, 0.1649926227, 0.7014177868, 0.687878607],
    [0.4678912192, 0.1540763822, 0.06010307574, 0.1318713131, 0.841644061, 0.4016636504],
    [0.6610658686, 0.6941332031, 0.5873421946, 0.5442743402, 0.3782924672, 0.6122280347],
    [0.574647078, 0.42044434, 0.6131809837, 0.6770220551, 0.6165412815, 0.6165412815]
])

rows = [
     "Frequency Test",
     "Frequency Test within a Block",
     "Run Test",
     "Longest Run of Ones in a Block",
     "Binary Matrix Rank Test",
     "Discrete Fourier Transform (Spectral) Test",
     "Non-Overlapping Template Matching Test",
     "Overlapping Template Matching Test",
     "Maurer's Universal Statistical test",
     "Linear Complexity Test",
     "Serial test a",
     "Serial test b",
     "Approximate Entropy Test",
     "Cumulative Sums (Forward) Test",
     "Cumulative Sums (Reverse) Test",
     "Random Excursion Test",
     "Random Excursion Variant Test"
]
columns = ["QTRNG_A", "QTRNG_B", "QPRNG_A", "QPRNG_B", "QHRNG_A", "QHRNG_B"]


# Create the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(data, annot=True, fmt=".4f", xticklabels=columns, yticklabels=rows, cmap="coolwarm")

# Add title and labels
#plt.title("Heatmap of Entropy Estimators", fontsize=16)
#plt.xlabel("Datasets", fontsize=12)
#plt.ylabel("Entropy Estimators", fontsize=12)

# Show the plot
#plt.tight_layout()
#plt.savefig("gururaja_entropy_heatmap.png", dpi=300, bbox_inches="tight")
#plt.show()

# Convert to DataFrame
#df = pd.DataFrame(data).T

# Generate heatmap
#plt.figure(figsize=(12, 8))
#sns.heatmap(, annot=True, cmap="coolwarm", cbar_kws={'label': 'P-value'}, fmt=".3f")
plt.title("NIST 800-22 Statistical Test P-Values")
plt.xlabel("ProposedSecure Key")
plt.ylabel("Tests")
plt.tight_layout()
plt.savefig("gururaja_1.tiff", dpi=300, bbox_inches="tight")  # Save as PNG with high resolution
plt.show()
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\acer\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\acer\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\acer\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#     self.io_loop.start()
# ...

# %%
pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the metrics
labels = ['Barbara', 'Cameraman', 'Pepper', 'Mandril']

# Differential Attack Metrics
npcr = [99.5941162109375, 99.609375, 99.652099609375, 99.5880126953125]
uaci = [33.1332337622549, 33.154075472962624, 33.50326238893995, 33.416771982230394]

# Statistical Analysis
psnr = [8.97160523969861, 8.438918687076194, 8.863331311716111, 9.712040463819262]
mse = [8239.860076904297, 9315.120819091797, 8447.870147705078, 6948.264053344727]
entropy = [7.993223564147437, 7.993971712169283, 7.997115670788833, 7.993354104652636]

# Correlation Coefficients
corr_horizontal = [-0.001345696616112369, -0.00010573013849392895, 0.0008042400228072978, -0.0028821678201163643]
corr_vertical = [0.0016979279130194098, -0.006098590494416285, 0.00685811157148028, -0.003974506130126212]
corr_diagonal = [0.0027301573440961365, -0.0030250618777796145, -0.004617585258883989, -0.007010823066106841]

# Avalanche Effect
avalanche_effect = [49.849891662597656, 49.993896484375, 50.12187957763672, 49.92809295654297]

# Chi-Square Test
chi_square = [0.4201, 1.5454, 0.4921, 0.8488]
critical_value = [293.2478350807012] * 4
deviation = [0.077880859375, 0.073883056640625, 0.04888916015625, 0.076629638671875]

# Create subplots for the metrics
fig, axs = plt.subplots(3, 2, figsize=(15, 12))

# Plot NPCR and UACI
axs[0, 0].bar(labels, npcr, color='blue', alpha=0.7, label='NPCR (%)')
axs[0, 0].set_title('NPCR (%)')
axs[0, 0].set_ylabel('Percentage')

axs[0, 1].bar(labels, uaci, color='orange', alpha=0.7, label='UACI (%)')
axs[0, 1].set_title('UACI (%)')
axs[0, 1].set_ylabel('Percentage')

# Plot PSNR and MSE
axs[1, 0].bar(labels, psnr, color='green', alpha=0.7, label='PSNR (dB)')
axs[1, 0].set_title('PSNR (dB)')
axs[1, 0].set_ylabel('Decibels')

axs[1, 1].bar(labels, mse, color='red', alpha=0.7, label='MSE')
axs[1, 1].set_title('MSE')
axs[1, 1].set_ylabel('Error')

# Plot Entropy and Avalanche Effect
axs[2, 0].plot(labels, entropy, marker='o', color='purple', label='Entropy')
axs[2, 0].set_title('Entropy')
axs[2, 0].set_ylabel('Bits')

axs[2, 1].bar(labels, avalanche_effect, color='brown', alpha=0.7, label='Avalanche Effect (%)')
axs[2, 1].set_title('Avalanche Effect (%)')
axs[2, 1].set_ylabel('Percentage')

# Adjust layout
plt.tight_layout()
plt.savefig("gururaja_2.png", dpi=300, bbox_inches="tight")  # Save as PNG with high resolution
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Data for the heatmap
data = np.array([
    [0.8411, 0.8037, 0.7918, 0.8206, 0.7944, 0.8178],  # Most common value estimate
    [0.7101, 0.8656, 0.8498, 1.0000, 0.6864, 1.0000],  # Collision test estimate
    [0.8395, 0.8559, 0.8308, 0.8469, 0.7830, 0.8486],  # Markov test estimate
    [0.5776, 0.5641, 0.5183, 0.5159, 0.6516, 0.5245],  # Compression test estimate
    [0.0860, 0.0860, 0.0860, 0.0860, 0.0860, 0.0860],  # T-Tuple test estimate
    [0.8425, 0.8039, 0.7921, 0.8221, 0.7959, 0.8192],  # Multi-most common in window
    [0.7924, 0.8020, 0.7789, 0.7866, 0.7975, 0.7872],  # Lag prediction test estimate
    [0.8412, 0.8037, 0.7918, 0.8206, 0.7944, 0.8179],  # LZ78Y prediction test estimate
    [1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000]   # Multi MMC Prediction
])

# Labels for the axes
rows = [
    "Most common value estimate", 
    "Collision test estimate", 
    "Markov test estimate", 
    "Compression test estimate", 
    "T-Tuple test estimate", 
    "Multi-most common in window", 
    "Lag prediction test estimate", 
    "LZ78Y prediction test estimate", 
    "Multi MMC Prediction"
]
columns = ["QTRNG_A", "QTRNG_B", "QPRNG_A", "QPRNG_B", "QHRNG_A", "QHRNG_B"]

# Create the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(data, annot=True, fmt=".4f", xticklabels=columns, yticklabels=rows, cmap="coolwarm")

# Add title and labels
plt.title("NIST 800-90B Minimal Entropy Estimators", fontsize=16)
plt.xlabel("Proposed Secure Key", fontsize=12)
plt.ylabel("Entropy Estimators", fontsize=12)

# Show the plot
plt.tight_layout()
plt.savefig("gururaja_entropy_heatmap.tiff", dpi=300, bbox_inches="tight")
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define datasets
Proposed_Quantum_Key_Encryption = ["QTRNG_A", "QTRNG_B", "QPRNG_A", "QPRNG_B", "QHRNG_A", "QHRNG_B"]
images = ["Barbara", "Cameraman", "Pepper", "Mandril"]
metrics = ["NPCR (%)", "UACI (%)", "PSNR (dB)", "MSE", "Entropy", "Chi-Square Statistic"]

# Data (add the given values in a structured format)
data = {
    "NPCR (%)": [
        [99.58, 99.63, 99.65, 99.60],
        [99.59, 99.61, 99.65, 99.59],
        [99.64, 99.64, 99.62, 99.59],
        [99.58, 99.57, 99.61, 99.57],
        [99.57, 99.59, 99.59, 99.66],
        [99.58, 99.58, 99.57, 99.55],
    ],
    "UACI (%)": [
        [33.49, 33.47, 33.50, 33.28],
        [33.13, 33.15, 33.50, 33.42],
        [33.44, 33.43, 33.51, 33.52],
        [33.28, 33.32, 33.28, 33.48],
        [33.44, 33.39, 33.50, 33.54],
        [33.28, 33.29, 33.33, 33.31],
    ],
    "PSNR (dB)": [
        [8.9138, 8.4157, 8.8633, 9.6806],
        [8.9716, 8.4389, 8.8633, 9.7120],
        [8.9139, 8.4263, 8.8951, 9.7014],
        [8.9275, 8.4163, 8.8901, 9.6532],
        [8.9227, 8.4049, 8.9143, 9.6634],
        [8.9381, 8.4172, 8.8550, 9.7129],
    ],
    "MSE": [
        [8350.30, 9365.06, 8447.87, 6998.76],
        [8239.86, 9315.12, 8447.87, 6948.26],
        [8350.05, 9342.30, 8386.38, 6965.27],
        [8323.93, 9363.67, 8395.97, 7042.98],
        [8333.10, 9388.36, 8349.29, 7026.50],
        [8303.63, 9361.74, 8464.13, 6946.90],
    ],
    "Entropy": [
        [7.9972, 7.9969, 7.9971, 7.9974],
        [7.9932, 7.9940, 7.9971, 7.9934],
        [7.9974, 7.9971, 7.9973, 7.9974],
        [7.9933, 7.9934, 7.9934, 7.9939],
        [7.9967, 7.9972, 7.9969, 7.9971],
        [7.9934, 7.9926, 7.9944, 7.9940],
    ],
    "Chi-Square Statistic": [
        [0.4201, 1.5454, 0.4921, 0.8488],
        [0.4201, 1.5454, 0.4921, 0.8488],
        [0.4201, 1.5454, 0.4921, 0.8488],
        [0.4201, 1.5454, 0.4921, 0.8488],
        [0.4201, 1.5454, 0.4921, 0.8488],
        [0.4201, 1.5454, 0.4921, 0.8488],
    ]
}

# Create line plots for NPCR, UACI, and PSNR
for metric in ["NPCR (%)", "UACI (%)", "PSNR (dB)"]:
    plt.figure(figsize=(10, 6))
    for i, image in enumerate(images):
        values = [data[metric][j][i] for j in range(len(Proposed_Quantum_Key_Encryption))]
        plt.plot(Proposed_Quantum_Key_Encryption, values, marker="o", label=image)
    plt.title(f"{metric} Across Quantum Key Encryption", fontsize=16)
    plt.xlabel("Proposed Quantum Key", fontsize=12)
    plt.ylabel(metric, fontsize=12)
    plt.legend(title="Image", fontsize=10)
    plt.grid(alpha=0.5)
    plt.tight_layout()
    plt.show()

# Heatmap for Entropy
entropy_data = np.array(data["Entropy"])
plt.figure(figsize=(10, 6))
sns.heatmap(entropy_data, annot=True, fmt=".4f", xticklabels=images, yticklabels=Proposed_Quantum_Key_Encryption, cmap="coolwarm")
plt.title("Entropy Across Quantum Key encrypted Images", fontsize=16)
plt.xlabel("Images", fontsize=12)
plt.ylabel("Proposed Quantum Key", fontsize=12)
plt.tight_layout()
plt.show()

# %%
pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Define datasets
Proposed_Quantum_Key_Encryption = ["QTRNG_A", "QTRNG_B", "QPRNG_A", "QPRNG_B", "QHRNG_A", "QHRNG_B"]
images = ["Barbara", "Cameraman", "Pepper", "Mandril"]
metrics = ["NPCR (%)", "UACI (%)", "PSNR (dB)", "MSE", "Entropy", "Chi-Square Statistic"]

# Data (add the given values in a structured format)
data = {
    "NPCR (%)": [
        [99.58, 99.63, 99.65, 99.60],
        [99.59, 99.61, 99.65, 99.59],
        [99.64, 99.64, 99.62, 99.59],
        [99.58, 99.57, 99.61, 99.57],
        [99.57, 99.59, 99.59, 99.66],
        [99.58, 99.58, 99.57, 99.55],
    ],
    "UACI (%)": [
        [33.49, 33.47, 33.50, 33.28],
        [33.13, 33.15, 33.50, 33.42],
        [33.44, 33.43, 33.51, 33.52],
        [33.28, 33.32, 33.28, 33.48],
        [33.44, 33.39, 33.50, 33.54],
        [33.28, 33.29, 33.33, 33.31],
    ],
    "PSNR (dB)": [
        [8.9138, 8.4157, 8.8633, 9.6806],
        [8.9716, 8.4389, 8.8633, 9.7120],
        [8.9139, 8.4263, 8.8951, 9.7014],
        [8.9275, 8.4163, 8.8901, 9.6532],
        [8.9227, 8.4049, 8.9143, 9.6634],
        [8.9381, 8.4172, 8.8550, 9.7129],
    ],
    "Entropy": [
        [7.9972, 7.9969, 7.9971, 7.9974],
        [7.9932, 7.9940, 7.9971, 7.9934],
        [7.9974, 7.9971, 7.9973, 7.9974],
        [7.9933, 7.9934, 7.9934, 7.9939],
        [7.9967, 7.9972, 7.9969, 7.9971],
        [7.9934, 7.9926, 7.9944, 7.9940],
    ],
    "Chi-Square Statistic": [
        [0.4201, 1.5454, 0.4921, 0.8488],
        [0.4201, 1.5454, 0.4921, 0.8488],
        [0.4201, 1.5454, 0.4921, 0.8488],
        [0.4201, 1.5454, 0.4921, 0.8488],
        [0.4201, 1.5454, 0.4921, 0.8488],
        [0.4201, 1.5454, 0.4921, 0.8488],
    ]
}

# Create directory for saving images
save_dir = "F:\NOV-Dec 2024 Paper Work"
os.makedirs(save_dir, exist_ok=True)

# Line plots for NPCR, UACI, and PSNR
for metric in ["NPCR (%)", "UACI (%)", "PSNR (dB)"]:
    plt.figure(figsize=(10, 6))
    for i, image in enumerate(images):
        values = [data[metric][j][i] for j in range(len(Proposed_Quantum_Key_Encryption))]
        plt.plot(Proposed_Quantum_Key_Encryption, values, marker="o", label=image)
    plt.title(f"{metric} Across Quantum Key Encryption", fontsize=16)
    plt.xlabel("Proposed_Quantum_Key", fontsize=12)
    plt.ylabel(metric, fontsize=12)
    plt.legend(title="Images", fontsize=10)
    plt.grid(alpha=0.5)
    plt.tight_layout()
    save_path = os.path.join(save_dir, f"{metric.replace(' ', '_').replace('(', '').replace(')', '')}_line_plot.png")
    plt.savefig(save_path)
    plt.close()

# Heatmap for Entropy
entropy_data = np.array(data["Entropy"])
plt.figure(figsize=(10, 6))
sns.heatmap(entropy_data, annot=True, fmt=".4f", xticklabels=images, yticklabels=Proposed_Quantum_Key_Encryption, cmap="coolwarm")
plt.title("Heatmap of Entropy Across Datasets and Images", fontsize=16)
plt.xlabel("Images", fontsize=12)
plt.ylabel("Proposed_Quantum_Key_Encryption", fontsize=12)
plt.tight_layout()
save_path = os.path.join(save_dir, "Entropy_Heatmap.png")
plt.savefig(save_path)
plt.close()

print(f"Plots saved in directory: {save_dir}")
# Out:
#   Cell In[14], line 57
#     save_dir = "F:\NOV-Dec 2024 Paper Work"
#                                            ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: malformed \N character escape

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Define datasets
Proposed_Quantum_Key_Encryption = ["QTRNG_A", "QTRNG_B", "QPRNG_A", "QPRNG_B", "QHRNG_A", "QHRNG_B"]
images = ["Barbara", "Cameraman", "Pepper", "Mandril"]
metrics = ["NPCR (%)", "UACI (%)", "PSNR (dB)", "Entropy", "Chi-Square Statistic"]

# Data
data = {
    "NPCR (%)": [
        [99.58, 99.63, 99.65, 99.60],
        [99.59, 99.61, 99.65, 99.59],
        [99.64, 99.64, 99.62, 99.59],
        [99.58, 99.57, 99.61, 99.57],
        [99.57, 99.59, 99.59, 99.66],
        [99.58, 99.58, 99.57, 99.55],
    ],
    "UACI (%)": [
        [33.49, 33.47, 33.50, 33.28],
        [33.13, 33.15, 33.50, 33.42],
        [33.44, 33.43, 33.51, 33.52],
        [33.28, 33.32, 33.28, 33.48],
        [33.44, 33.39, 33.50, 33.54],
        [33.28, 33.29, 33.33, 33.31],
    ],
    "PSNR (dB)": [
        [8.9138, 8.4157, 8.8633, 9.6806],
        [8.9716, 8.4389, 8.8633, 9.7120],
        [8.9139, 8.4263, 8.8951, 9.7014],
        [8.9275, 8.4163, 8.8901, 9.6532],
        [8.9227, 8.4049, 8.9143, 9.6634],
        [8.9381, 8.4172, 8.8550, 9.7129],
    ],
    "Entropy": [
        [7.9972, 7.9969, 7.9971, 7.9974],
        [7.9932, 7.9940, 7.9971, 7.9934],
        [7.9974, 7.9971, 7.9973, 7.9974],
        [7.9933, 7.9934, 7.9934, 7.9939],
        [7.9967, 7.9972, 7.9969, 7.9971],
        [7.9934, 7.9926, 7.9944, 7.9940],
    ],
    "Chi-Square Statistic": [
        [0.4201, 1.5454, 0.4921, 0.8488],
        [0.4201, 1.5454, 0.4921, 0.8488],
        [0.4201, 1.5454, 0.4921, 0.8488],
        [0.4201, 1.5454, 0.4921, 0.8488],
        [0.4201, 1.5454, 0.4921, 0.8488],
        [0.4201, 1.5454, 0.4921, 0.8488],
    ]
}

# Create directory for saving images
save_dir = r"F:\NOV-Dec 2024 Paper Work\Result and Discussion-Image\New folder"
os.makedirs(save_dir, exist_ok=True)

# Line plots for NPCR, UACI, and PSNR
for metric in ["NPCR (%)", "UACI (%)", "PSNR (dB)"]:
    plt.figure(figsize=(10, 6))
    for i, image in enumerate(images):
        values = [data[metric][j][i] for j in range(len(Proposed_Quantum_Key_Encryption))]
        plt.plot(Proposed_Quantum_Key_Encryption, values, marker="o", label=image)
    plt.title(f"{metric} Across Quantum Key Encryption", fontsize=16)
    plt.xlabel("Proposed Quantum Key", fontsize=12)
    plt.ylabel(metric, fontsize=12)
    plt.legend(title="Images", fontsize=10)
    plt.grid(alpha=0.5)
    plt.tight_layout()
    save_path = os.path.join(save_dir, f"{metric.replace(' ', '_').replace('(', '').replace(')', '')}_line_plot.tiff")
    plt.savefig(save_path)
    plt.close()

# Heatmap for Entropy
entropy_data = np.array(data["Entropy"])
plt.figure(figsize=(10, 6))
sns.heatmap(entropy_data, annot=True, fmt=".4f", xticklabels=images, yticklabels=Proposed_Quantum_Key_Encryption, cmap="coolwarm")
plt.title("Entropy Across Quantum Key Encryption", fontsize=16)
plt.xlabel("Images", fontsize=12)
plt.ylabel("Proposed Quantum Key Encryption", fontsize=12)
plt.tight_layout()
save_path = os.path.join(save_dir, "Entropy_Heatmap.tiff")
plt.savefig(save_path)
plt.close()

print(f"Plots saved in directory: {os.path.abspath(save_dir)}")
# Out:
# Plots saved in directory: /home/jovyan/F:\NOV-Dec 2024 Paper Work\Result and Discussion-Image\New folder

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# Data for visualization
datasets = ["QTRNG_A", "QTRNG_B", "QPRNG_A", "QPRNG_B", "QHRNG_A", "QHRNG_B"]
metrics = ["Horizontal", "Vertical", "Diagonal"]
data = {
    "Horizontal": [
        [-0.0041, 2.08E-05, 0.0008, 0.0018],  # Data 1a
        [-0.0013, -0.0001, 0.0008, -0.0029],  # Data 1b
        [0.0004, 0.0033, -0.0018, 0.0017],    # Data 2a
        [0.0012, 0.0073, -0.0056, 0.0025],    # Data 2b
        [-0.0042, 0.0032, -0.0018, -0.0029],  # Data 3a
        [-0.0038, 0.0008, 0.0044, -0.0004],   # Data 3b
    ],
    "Vertical": [
        [-0.0024, 0.0021, 0.0069, -0.0029],  # Data 1a
        [0.0017, -0.0061, 0.0069, -0.0040],  # Data 1b
        [0.0042, 0.0015, -0.0050, 0.0017],   # Data 2a
        [0.0001, -0.0029, -0.0029, -0.0016], # Data 2b
        [-0.0033, -0.0044, 0.0013, 0.0040],  # Data 3a
        [0.0027, 0.0020, 0.0047, 0.0015],    # Data 3b
    ],
    "Diagonal": [
        [-0.0001, 0.0047, -0.0046, 0.0017],  # Data 1a
        [0.0027, -0.0030, -0.0046, -0.0070], # Data 1b
        [-0.0019, 0.0005, -0.0052, 0.0010],  # Data 2a
        [-0.0031, -0.0020, 0.0007, -0.0010], # Data 2b
        [-0.0008, -0.0017, 0.0037, -0.0016], # Data 3a
        [0.0003, 0.0014, -0.0025, -0.0004],  # Data 3b
    ],
}

# Save directory for plots
save_dir = "./visualizatio"
os.makedirs(save_dir, exist_ok=True)

# Function to save individual plots for each metric
for metric in metrics:
    fig, ax = plt.subplots(figsize=(8, 6))
    for i, dataset in enumerate(datasets):
        ax.bar(
            np.arange(len(data[metric][i])) + i * 0.15,
            data[metric][i],
            width=0.15,
            label=dataset,
        )
    ax.set_xlabel("Images", fontsize=12)
    ax.set_ylabel(f"{metric} Values", fontsize=12)
    ax.set_title(f"{metric} Correlatioms Across Quantum Key Encryption", fontsize=14)
    ax.set_xticks(np.arange(len(data[metric][0])) + 0.15 * (len(datasets) - 1) / 2)
    ax.set_xticklabels(["Barbara", "Cameraman", "Pepper", "Mandril"], fontsize=10)
    ax.legend(title="Quantum Key", fontsize=10)
    ax.grid(axis="y", linestyle="--", alpha=0.6)
    
    # Save the plot
    save_path = os.path.join(save_dir, f"{metric}_correlations.tiff")
    plt.tight_layout()
    plt.savefig(save_path)
    plt.close()

print(f"Plots saved in directory: {save_dir}")
# Out:
# Plots saved in directory: ./visualizatio

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Define datasets
Proposed_Quantum_Key_Encryption = ["QTRNG_A", "QTRNG_B", "QPRNG_A", "QPRNG_B", "QHRNG_A", "QHRNG_B"]
images = ["Barbara", "Cameraman", "Pepper", "Mandril"]
metrics = ["MSE"]

# Data
data = {
     "MSE": [
        [8350.3040, 9365.0643 , 8447.8701, 6998.7590],
        [8239.8600, 9315.1208, 8447.8701, 6948.2640],
        [8350.0510, 9342.3016, 8386.3832, 6965.2669],
        [8323.9345, 9363.6675, 8395.9727, 7042.9812],
        [8333.0950, 9388.3557 ,8349.2938, 7026.5041],
        [8303.6304, 9361.7397, 8464.1331, 6946.8986],
    ]
}
# Create directory for saving images
save_dir = r"F:\NOV-Dec 2024 Paper Work\Result and Discussion-Image\New folder"
os.makedirs(save_dir, exist_ok=True)

# Line plots for NPCR, UACI, and PSNR
for metric in ["MSE"]:
    plt.figure(figsize=(10, 6))
    for i, image in enumerate(images):
        values = [data[metric][j][i] for j in range(len(Proposed_Quantum_Key_Encryption))]
        plt.plot(Proposed_Quantum_Key_Encryption, values, marker="o", label=image)
    plt.title(f"{metric} Across Quantum Key Encryption", fontsize=16)
    plt.xlabel("Proposed Quantum Key", fontsize=12)
    plt.ylabel(metric, fontsize=12)
    plt.legend(title="Images", fontsize=10)
    plt.grid(alpha=0.5)
    plt.tight_layout()
    plt.show()
    save_path = os.path.join(save_dir, f"{metric.replace(' ', '_').replace('(', '').replace(')', '')}_line_plot.tiff")
    plt.savefig(save_path)
    plt.close()
print(f"Plots saved in directory: {save_dir}")
# Out:
# Plots saved in directory: F:\NOV-Dec 2024 Paper Work\Result and Discussion-Image\New folder

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Define datasets
Proposed_Quantum_Key_Encryption = ["QTRNG_A", "QTRNG_B", "QPRNG_A", "QPRNG_B", "QHRNG_A", "QHRNG_B"]
images = ["Barbara", "Cameraman", "Pepper", "Mandril"]
metrics = ["MSE"]

# Data
data = {
    "MSE": [
        [8350.3040, 9365.0643, 8447.8701, 6998.7590],
        [8239.8600, 9315.1208, 8447.8701, 6948.2640],
        [8350.0510, 9342.3016, 8386.3832, 6965.2669],
        [8323.9345, 9363.6675, 8395.9727, 7042.9812],
        [8333.0950, 9388.3557, 8349.2938, 7026.5041],
        [8303.6304, 9361.7397, 8464.1331, 6946.8986],
    ]
}

# Create directory for saving images
save_dir = r"F:\NOV-Dec 2024 Paper Work\Result and Discussion-Image\New folder"
os.makedirs(save_dir, exist_ok=True)

# Plot for MSE
for metric in ["MSE"]:
    plt.figure(figsize=(10, 6))
    
    # Plot each image's MSE data
    for i, image in enumerate(images):
        values = [data[metric][j][i] for j in range(len(Proposed_Quantum_Key_Encryption))]
        plt.plot(
            Proposed_Quantum_Key_Encryption, 
            values, 
            marker="o", 
            label=image
        )
    
    # Add title and labels
    plt.title(f"{metric} Across Quantum Key Encryption", fontsize=16)
    plt.xlabel("Proposed Quantum Key", fontsize=12)
    plt.ylabel(metric, fontsize=12)
    
    # Add legend with image names at the top corner
    plt.legend(
        title="Images", 
        fontsize=10, 
        loc="upper left", 
        bbox_to_anchor=(1.05, 1)  # Move the legend outside the plot
    )
    
    # Add grid for better visibility
    plt.grid(alpha=0.5)
    
    # Adjust layout to fit everything
    plt.tight_layout()
    
    # Display plot
    plt.show()
    
    # Save plot to file
    save_path = os.path.join(save_dir, f"{metric.replace(' ', '_').replace('(', '').replace(')', '')}_line_plot.tiff")
    plt.savefig(save_path)
    plt.close()

print(f"Plots saved in directory: {save_dir}")
# Out:
# Plots saved in directory: F:\NOV-Dec 2024 Paper Work\Result and Discussion-Image\New folder

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# Define datasets
Proposed_Quantum_Key_Encryption = ["DATA_A", "DATA_B", "DATA_A", "DATA_B", "DATA_A", "DATA_B"]
images = ["Barbara", "Cameraman", "Pepper", "Mandril"]
metrics = ["MSE"]

# Data
data = {
    "MSE": [
        [8350.3040, 9365.0643, 8447.8701, 6998.7590],
        [8239.8600, 9315.1208, 8447.8701, 6948.2640],
        [8350.0510, 9342.3016, 8386.3832, 6965.2669],
        [8323.9345, 9363.6675, 8395.9727, 7042.9812],
        [8333.0950, 9388.3557, 8349.2938, 7026.5041],
        [8303.6304, 9361.7397, 8464.1331, 6946.8986],
    ]
}

# Create directory for saving images
save_dir = r"F:\NOV-Dec 2024 Paper Work\Result and Discussion-Image\New folder
os.makedirs(save_dir, exist_ok=True)

# Plot for MSE
for metric in ["MSE"]:
    plt.figure(figsize=(10, 6))
    
    # Plot each image's MSE data
    for i, image in enumerate(images):
        values = [data[metric][j][i] for j in range(len(Proposed_Quantum_Key_Encryption))]
        plt.plot(
            , 
            values, 
            marker="o", 
            label=image
        )
    
    # Add title and labels
    plt.title(f"{metric} Across Quantum Key Encryption", fontsize=16)
    plt.xlabel("DATA", fontsize=12)
    plt.ylabel(metric, fontsize=12)
    
    # Add legend inside the plot (top-right corner)
    plt.legend(
        title="Images", 
        fontsize=10, 
        loc="upper right"  # Position inside the graph
    )
    
    # Add grid for better visibility
    plt.grid(alpha=0.5)
    
    # Adjust layout to fit everything
    plt.tight_layout()
    
    # Save plot to file
    save_path = os.path.join(save_dir, f"{metric.replace(' ', '_').replace('(', '').replace(')', '')}_line_plot.tiff")
    plt.savefig(save_path, format='tiff', dpi=300)  # Ensure high-quality saving
    plt.close()

print(f"Plots saved in directory: {save_dir}")
# Out:
# Plots saved in directory: F:\NOV-Dec 2024 Paper Work\Result and Discussion-Image\New folder
